# %%
import rasterio
from rasterio.plot import show

# %%
path='/Volumes/GoogleDrive/Geteilte Ablagen/BD_EVENTOS/Simulaciones_Fede/Topog_2'
dem_path = f'{path}/Clip_01_DEM_Fixed.tif'
geo_path = f'{path}/USG.shp'

# %%
import rasterio
dem = rasterio.open(dem_path)
show(dem)
# Out:
# <AxesSubplot:>

# %%
from modelos import Catani, plot_rasterio
zs = Catani(dem_path, geo_path, 0.1, 'Hmax', f'{path}/zs_new.tif')
plot_rasterio(zs)
